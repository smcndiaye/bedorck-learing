# %%
import boto3
import logging
import json
import random
import amazon_video_util
from datetime import datetime, timedelta, timezone

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='[%(levelname)s] %(message)s')
logger = logging.getLogger(__name__)

# %%
logging.basicConfig(level=logging.DEBUG, format='[%(levelname)s] %(message)s')
logger = logging.getLogger(__name__)

# Constants
DEFAULT_MODEL_ID = "amazon.nova-reel-v1:0"

def setup_aws_session(region="us-east-1"):
    """Set up AWS session with default region"""
    boto3.setup_default_session(region_name=region)
    logger.info("AWS SDK session defaults have been set.")


def generate_video(s3_destination_bucket, video_prompt, model_id=DEFAULT_MODEL_ID):
    """
    Generate a video using the provided prompt.
    
    Args:
        s3_destination_bucket (str): The S3 bucket where the video will be stored
        video_prompt (str): Text prompt describing the desired video
    """
    # Set up the S3 client
    s3_client = boto3.client("s3")

    # Create the S3 bucket
    s3_client.create_bucket(Bucket=s3_destination_bucket)

    # Create the Bedrock Runtime client
    bedrock_runtime = boto3.client("bedrock-runtime")

    model_input = {
        "taskType": "TEXT_VIDEO",
        "textToVideoParams": {
            "text": video_prompt,
        },
        "videoGenerationConfig": {
            "durationSeconds": 6,  # 6 is the only supported value currently
            "fps": 24,  # 24 is the only supported value currently
            "dimension": "1280x720",  # "1280x720" is the only supported value currently
            "seed": random.randint(
                0, 2147483648
            ),  # A random seed guarantees we'll get a different result each time this code runs
        },
    }

    try:
        # Start the asynchronous video generation job
        invocation = bedrock_runtime.start_async_invoke(
            modelId=model_id,
            modelInput=model_input,
            outputDataConfig={"s3OutputDataConfig": {"s3Uri": f"s3://{s3_destination_bucket}"}},
        )

        # Store the invocation ARN
        invocation_arn = invocation["invocationArn"]

        # Pretty print the response JSON
        logger.info("\nResponse:")
        logger.info(json.dumps(invocation, indent=2, default=str))

        # Save the invocation details for later reference
        amazon_video_util.save_invocation_info(invocation, model_input)

        return invocation_arn

    except Exception as e:
        logger.error(e)
        return None

def check_job_status(invocation_arn):
    """Check status of a specific job using get_async_invoke()"""
    bedrock_runtime = boto3.client("bedrock-runtime")
    try:
        response = bedrock_runtime.get_async_invoke(
            invocationArn=invocation_arn
        )
        
        status = response["status"]
        logger.info(f"Status: {status}")
        logger.info("\nFull response:")
        logger.info(json.dumps(response, indent=2, default=str))
        return response
    except Exception as e:
        logger.error(f"Error checking job status: {e}")
        return None

def list_job_statuses(max_results=10, status_filter="InProgress"):
    """List all video generation jobs with optional filtering"""
    bedrock_runtime = boto3.client("bedrock-runtime")
    try:
        invocation = bedrock_runtime.list_async_invokes(
            maxResults=max_results,
            statusEquals=status_filter,
        )
        
        logger.info("Invocation Jobs:")
        logger.info(json.dumps(invocation, indent=2, default=str))
        return invocation
    except Exception as e:
        logger.error(f"Error listing jobs: {e}")
        return None

def monitor_recent_jobs(duration_hours=1):
    """Monitor and download videos from the past N hours"""
    from_submit_time = datetime.now(timezone.utc) - timedelta(hours=duration_hours)
    return amazon_video_util.monitor_and_download_videos("output", submit_time_after=from_submit_time)


def main():
    # Initialize the AWS session
    setup_aws_session()

    # Configuration
    S3_BUCKET = "bedrock-video-generation-us-east-1-ip1n64"  # Change this to your unique bucket name
    VIDEO_PROMPT = "a Cat and a dog runing on the surface of the moon."
    MODEL_ID = "amazon.nova-reel-v1:0"

    # Generate video
    invocation_arn = generate_video(S3_BUCKET, VIDEO_PROMPT, MODEL_ID)
    if not invocation_arn:
        logger.error("Failed to start video generation")
        exit(1)

    # Check initial status
    logger.info("\nChecking initial job status...")
    check_job_status(invocation_arn)

    # List all in-progress jobs
    logger.info("\nListing all in-progress jobs...")
    list_job_statuses()

    # Monitor and download the video
    logger.info("\nMonitoring job and waiting for completion...")
    local_file_path = amazon_video_util.monitor_and_download_video(invocation_arn, "output")

    if local_file_path:
        logger.info(f"\nVideo successfully generated and downloaded to: {local_file_path}")
    else:
        logger.info("\nFailed to generate or download video")

if __name__ == "__main__":
    main()
# Out:
# [DEBUG] Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# [DEBUG] Changing event name from before-call.apigateway to before-call.api-gateway
# [DEBUG] Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# [DEBUG] Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# [DEBUG] Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# [DEBUG] Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# [DEBUG] Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# [DEBUG] Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# [DEBUG] Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# [DEBUG] Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# [DEBUG] Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# [DEBUG] Setting config variable for region to 'us-east-1'
# [INFO] AWS SDK session defaults have been set.
# [DEBUG] IMDS ENDPOINT: http://169.254.169.254/
# [DEBUG] Looking for credentials via: env
# [DEBUG] Looking for credentials via: assume-role
# [DEBUG] Looking for credentials via: assume-role-with-web-identity
# [DEBUG] Looking for credentials via: sso
# [DEBUG] Looking for credentials via: shared-credentials-file
# [INFO] Found credentials in shared credentials file: ~/.aws/credentials
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\endpoints.json
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\sdk-default-configuration.json
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002BEA2D8F380>
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\service-2.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\service-2.sdk-extras.json
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\endpoint-rule-set-1.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\partitions.json
# [DEBUG] Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x000002BEA2D089A0>
# [DEBUG] Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x000002BEB4BA3D80>
# [DEBUG] Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x000002BEA2D08720>
# [DEBUG] Looking for endpoint for s3 via: environment_service
# [DEBUG] Looking for endpoint for s3 via: environment_global
# [DEBUG] Looking for endpoint for s3 via: config_service
# [DEBUG] Looking for endpoint for s3 via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Setting s3 timeout as (60, 60)
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\_retry.json
# [DEBUG] Registering retry handlers for service: s3
# [DEBUG] Registering S3 region redirector handler
# [DEBUG] Registering S3Express Identity Resolver
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function validate_bucket_name at 0x000002BEA2D8FBA0>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function remove_bucket_from_url_paths_from_model at 0x000002BEA2DB1DA0>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <botocore.utils.S3RegionRedirectorv2 object at 0x000002BEB6A4B410>>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <bound method ClientCreator._inject_s3_input_parameters of <botocore.client.ClientCreator object at 0x000002BEB16D25F0>>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x000002BEA2DB1F80>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <botocore.utils.S3RegionRedirectorv2 object at 0x000002BEB6A4B410>>
# [DEBUG] Calling endpoint provider with parameters: {'Bucket': 'bedrock-video-generation-us-east-1-ip1n64', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'DisableAccessPoints': True, 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True, 'UseS3ExpressControlEndpoint': True}
# [DEBUG] Endpoint provider result: https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com
# [DEBUG] Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "None"
# [DEBUG] Selected auth type "v4" as "v4" with signing context params: {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_expect_header at 0x000002BEA2D8FF60>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <botocore.utils.S3ExpressIdentityResolver object at 0x000002BEB6A4B530>>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=CreateBucket) with params: {'url_path': '', 'query_string': {}, 'method': 'PUT', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'auth_path': '/bedrock-video-generation-us-east-1-ip1n64/', 'url': 'https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB4C87890>, 'has_streaming_input': False, 'auth_type': 'v4', 'unsigned_payload': None, 's3_redirect': {'redirected': False, 'bucket': 'bedrock-video-generation-us-east-1-ip1n64', 'params': {'Bucket': 'bedrock-video-generation-us-east-1-ip1n64'}}, 'input_params': {'Bucket': 'bedrock-video-generation-us-east-1-ip1n64'}, 'signing': {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# [DEBUG] Event request-created.s3.CreateBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB3F46EB0>>
# [DEBUG] Event choose-signer.s3.CreateBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x000002BEB16D25F0>>
# [DEBUG] Event choose-signer.s3.CreateBucket: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <function remove_arn_from_signing_path at 0x000002BEA2DB1EE0>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <function _set_extra_headers_for_unsigned_request at 0x000002BEA2DB25C0>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <botocore.utils.S3ExpressIdentityResolver object at 0x000002BEB6A4B530>>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# PUT
# /
#
# host:bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20250202T182251Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182251Z
# 20250202/us-east-1/s3/aws4_request
# f87bd91957f02e0a8183609fa5c08021a456bfa09f8059d2f8b0c65e42e767f5
# [DEBUG] Signature:
# 75798e678b8b4cbe7e75f1e802b02c63d9d86c0fc727f7bbdd327b559274eda7
# [DEBUG] Event request-created.s3.CreateBucket: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=PUT, url=https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com/, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182251Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=75798e678b8b4cbe7e75f1e802b02c63d9d86c0fc727f7bbdd327b559274eda7', 'amz-sdk-invocation-id': b'53fac104-0ac0-446d-b408-3bde6d17075c', 'amz-sdk-request': b'attempt=1', 'Content-Length': '0'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com:443
# [DEBUG] https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com:443 "PUT / HTTP/1.1" 200 0
# [DEBUG] Event before-parse.s3.CreateBucket: calling handler <function _handle_200_error at 0x000002BEA2DB22A0>
# [DEBUG] Event before-parse.s3.CreateBucket: calling handler <function handle_expires_header at 0x000002BEA2DB20C0>
# [DEBUG] Response headers: {'x-amz-id-2': '97xZoG/wlH5DZhIj/P8dVEL7Dp+PZ8yGaPijG5kTNh/y+MVmItJg8G4qCwRDlsOzGvCZPNrcYE52TTWt9DIWBtyYzrhKzKjL', 'x-amz-request-id': 'YZAT0CVGNJA2CSF9', 'Date': 'Sun, 02 Feb 2025 18:22:53 GMT', 'Location': '/bedrock-video-generation-us-east-1-ip1n64', 'Content-Length': '0', 'Server': 'AmazonS3'}
# [DEBUG] Response body:
# b''
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <function _update_status_code at 0x000002BEA2DB23E0>
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB3F47A10>
# [DEBUG] No retry needed.
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <bound method S3RegionRedirectorv2.redirect_from_error of <botocore.utils.S3RegionRedirectorv2 object at 0x000002BEB6A4B410>>
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002BEA2D8F380>
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\bedrock-runtime\2023-09-30\service-2.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\bedrock-runtime\2023-09-30\endpoint-rule-set-1.json.gz
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002BEA2D08720>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.StartAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] injecting idempotency token (2dcdd920-4976-4c14-80de-bf34aa2dab0b) into param 'clientRequestToken'.
# [DEBUG] Event before-parameter-build.bedrock-runtime.StartAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=StartAsyncInvoke) with params: {'url_path': '/async-invoke', 'query_string': {}, 'method': 'POST', 'headers': {'Content-Type': 'application/json', 'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'{"modelId": "amazon.nova-reel-v1:0", "modelInput": {"taskType": "TEXT_VIDEO", "textToVideoParams": {"text": "a Cat and a dog runing on the surface of the moon."}, "videoGenerationConfig": {"durationSeconds": 6, "fps": 24, "dimension": "1280x720", "seed": 1682964571}}, "outputDataConfig": {"s3OutputDataConfig": {"s3Uri": "s3://bedrock-video-generation-us-east-1-ip1n64"}}, "clientRequestToken": "2dcdd920-4976-4c14-80de-bf34aa2dab0b"}', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB3F14F50>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.StartAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEA33EC130>>
# [DEBUG] Event choose-signer.bedrock-runtime.StartAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# POST
# /async-invoke
#
# content-type:application/json
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182252Z
#
# content-type;host;x-amz-date
# 20f197f05456277ef7a1276730b609346edb6d5c9d46a7d4addd60d8493ffbed
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182252Z
# 20250202/us-east-1/bedrock/aws4_request
# 946ae7fa04529d92104901bbf04c808519ef5ad5d0b6916fed6dc87de88ba5e6
# [DEBUG] Signature:
# a2f819f45d97864aaaa9520598dfcf13fd537526ca06168321f90f0b177ed5c3
# [DEBUG] Event request-created.bedrock-runtime.StartAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke, headers={'Content-Type': b'application/json', 'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182252Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=content-type;host;x-amz-date, Signature=a2f819f45d97864aaaa9520598dfcf13fd537526ca06168321f90f0b177ed5c3', 'amz-sdk-invocation-id': b'bec67058-3eeb-4091-90fb-49b6619d357a', 'amz-sdk-request': b'attempt=1', 'Content-Length': '435'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "POST /async-invoke HTTP/1.1" 200 84
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'c6264e3e-0e8d-44a6-9a69-f3aac8ee838b'}
# [DEBUG] Response body:
# b'{"invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm"}'
# [DEBUG] Event needs-retry.bedrock-runtime.StartAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB475D390>
# [DEBUG] No retry needed.
# [INFO]
# Response:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "c6264e3e-0e8d-44a6-9a69-f3aac8ee838b",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Sun, 02 Feb 2025 18:22:53 GMT",
#       "content-type": "application/json",
#       "content-length": "84",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "c6264e3e-0e8d-44a6-9a69-f3aac8ee838b"
#     },
#     "RetryAttempts": 0
#   },
#   "invocationArn": "arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm"
# }
# [INFO] Getting async invoke details for ARN: arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB24F7B60>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB24F7A10>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A430118855470%253Aasync-invoke%252Fqbzshyxunrgm
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182253Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182253Z
# 20250202/us-east-1/bedrock/aws4_request
# fa234bb6ce3be2376e66d2cedfefe996bdf97f5ce1ae6d3c603cc165861a7bb9
# [DEBUG] Signature:
# d40b885ecf2bc5e60be78a0d85ab42fe6c601756d083649f59255ca9c55f6adc
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182253Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=d40b885ecf2bc5e60be78a0d85ab42fe6c601756d083649f59255ca9c55f6adc', 'amz-sdk-invocation-id': b'f0e9d450-74f8-4cc8-894b-e34e782553d8', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm HTTP/1.1" 200 437
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:53 GMT', 'Content-Type': 'application/json', 'Content-Length': '437', 'Connection': 'keep-alive', 'x-amzn-RequestId': '636bbb79-f5b3-4f16-bbc3-a205aa74d107'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"2dcdd920-4976-4c14-80de-bf34aa2dab0b","invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm","lastModifiedTime":"2025-02-02T18:22:53Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"}},"status":"InProgress","submitTime":"2025-02-02T18:22:53Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB2751940>
# [DEBUG] No retry needed.
# [INFO] Generated folder name: 2025-02-02_19-22-53_qbzshyxunrgm
# [INFO] Saving invocation info to folder: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-02_19-22-53_qbzshyxunrgm
# [INFO] Saved start_async_invoke_response.json
# [INFO] Saved model_input.json
# [INFO]
# Checking initial job status...
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002BEA2D8F380>
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002BEA2D08720>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB4C87890>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB62FCE20>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A430118855470%253Aasync-invoke%252Fqbzshyxunrgm
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182254Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182254Z
# 20250202/us-east-1/bedrock/aws4_request
# 201f2f22c962788d86215949c4951d470ce3b52a7023cd728c46ed0d47be54bb
# [DEBUG] Signature:
# e34c2590232f4b9c829ef9925ba4ca8f84e7b9ad5b407a44063ba1e87ced637d
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182254Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=e34c2590232f4b9c829ef9925ba4ca8f84e7b9ad5b407a44063ba1e87ced637d', 'amz-sdk-invocation-id': b'd7f7d42f-a28b-41b9-a2e3-e4405d1479ba', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm HTTP/1.1" 200 437
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:54 GMT', 'Content-Type': 'application/json', 'Content-Length': '437', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'b956ec14-a787-470b-806d-4e32d0e0cd42'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"2dcdd920-4976-4c14-80de-bf34aa2dab0b","invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm","lastModifiedTime":"2025-02-02T18:22:53Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"}},"status":"InProgress","submitTime":"2025-02-02T18:22:53Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB62FCD50>
# [DEBUG] No retry needed.
# [INFO] Status: InProgress
# [INFO]
# Full response:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "b956ec14-a787-470b-806d-4e32d0e0cd42",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Sun, 02 Feb 2025 18:22:54 GMT",
#       "content-type": "application/json",
#       "content-length": "437",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "b956ec14-a787-470b-806d-4e32d0e0cd42"
#     },
#     "RetryAttempts": 0
#   },
#   "invocationArn": "arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm",
#   "modelArn": "arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0",
#   "clientRequestToken": "2dcdd920-4976-4c14-80de-bf34aa2dab0b",
#   "status": "InProgress",
#   "submitTime": "2025-02-02 18:22:53+00:00",
#   "lastModifiedTime": "2025-02-02 18:22:53+00:00",
#   "outputDataConfig": {
#     "s3OutputDataConfig": {
#       "s3Uri": "s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"
#     }
#   }
# }
# [INFO]
# Listing all in-progress jobs...
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002BEA2D8F380>
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002BEA2D08720>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.ListAsyncInvokes: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.ListAsyncInvokes: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=ListAsyncInvokes) with params: {'url_path': '/async-invoke', 'query_string': {'maxResults': 10, 'statusEquals': 'InProgress'}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke?maxResults=10&statusEquals=InProgress', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB4C87890>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.ListAsyncInvokes: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB2D63F50>>
# [DEBUG] Event choose-signer.bedrock-runtime.ListAsyncInvokes: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke
# maxResults=10&statusEquals=InProgress
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182254Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182254Z
# 20250202/us-east-1/bedrock/aws4_request
# e45697315abab87272195263cb1656f278bb32c57365f48afa57dd607e29a5fa
# [DEBUG] Signature:
# dc602f85805e2acf1e17b2cf208e901b20f1eb4f31abaff56493b7579f56c398
# [DEBUG] Event request-created.bedrock-runtime.ListAsyncInvokes: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke?maxResults=10&statusEquals=InProgress, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182254Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=dc602f85805e2acf1e17b2cf208e901b20f1eb4f31abaff56493b7579f56c398', 'amz-sdk-invocation-id': b'684b6425-2948-4488-943b-8d9cab1dd333', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke?maxResults=10&statusEquals=InProgress HTTP/1.1" 200 464
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '464', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'e5f99c2f-dd7c-4815-a8fa-62c47bc04237'}
# [DEBUG] Response body:
# b'{"asyncInvokeSummaries":[{"clientRequestToken":"2dcdd920-4976-4c14-80de-bf34aa2dab0b","invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm","lastModifiedTime":"2025-02-02T18:22:53Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"}},"status":"InProgress","submitTime":"2025-02-02T18:22:53Z"}]}'
# [DEBUG] Event needs-retry.bedrock-runtime.ListAsyncInvokes: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB4258F50>
# [DEBUG] No retry needed.
# [INFO] Invocation Jobs:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "e5f99c2f-dd7c-4815-a8fa-62c47bc04237",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Sun, 02 Feb 2025 18:22:55 GMT",
#       "content-type": "application/json",
#       "content-length": "464",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "e5f99c2f-dd7c-4815-a8fa-62c47bc04237"
#     },
#     "RetryAttempts": 0
#   },
#   "asyncInvokeSummaries": [
#     {
#       "invocationArn": "arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm",
#       "modelArn": "arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0",
#       "clientRequestToken": "2dcdd920-4976-4c14-80de-bf34aa2dab0b",
#       "status": "InProgress",
#       "submitTime": "2025-02-02 18:22:53+00:00",
#       "lastModifiedTime": "2025-02-02 18:22:53+00:00",
#       "outputDataConfig": {
#         "s3OutputDataConfig": {
#           "s3Uri": "s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"
#         }
#       }
#     }
#   ]
# }
# [INFO]
# Monitoring job and waiting for completion...
# [INFO] Monitoring and downloading video for ARN: arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB24F7B60>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB24F7A10>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A430118855470%253Aasync-invoke%252Fqbzshyxunrgm
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182255Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182255Z
# 20250202/us-east-1/bedrock/aws4_request
# 0eaa6902526b58ebf185530cfbc75efa7675796526bcea418ede779c41364c03
# [DEBUG] Signature:
# 716f1f7a3e13beb9981314cf8de3b2872d981a0a108113b67993b09288ec6825
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182255Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=716f1f7a3e13beb9981314cf8de3b2872d981a0a108113b67993b09288ec6825', 'amz-sdk-invocation-id': b'32a1e7bf-8760-4422-b2e8-23ea35af5f81', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm HTTP/1.1" 200 437
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '437', 'Connection': 'keep-alive', 'x-amzn-RequestId': '4a537931-cd34-4fd7-a811-a0ecf2adac3c'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"2dcdd920-4976-4c14-80de-bf34aa2dab0b","invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm","lastModifiedTime":"2025-02-02T18:22:53Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"}},"status":"InProgress","submitTime":"2025-02-02T18:22:53Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB2751940>
# [DEBUG] No retry needed.
# [INFO] Monitoring and downloading in-progress video for ARN: arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB24F7B60>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB24F7A10>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A430118855470%253Aasync-invoke%252Fqbzshyxunrgm
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182255Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182255Z
# 20250202/us-east-1/bedrock/aws4_request
# 0eaa6902526b58ebf185530cfbc75efa7675796526bcea418ede779c41364c03
# [DEBUG] Signature:
# 716f1f7a3e13beb9981314cf8de3b2872d981a0a108113b67993b09288ec6825
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182255Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=716f1f7a3e13beb9981314cf8de3b2872d981a0a108113b67993b09288ec6825', 'amz-sdk-invocation-id': b'd0df42e4-a71a-4a39-af53-36d4664254f5', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm HTTP/1.1" 200 437
# [DEBUG] Response headers: {'Date': 'Sun, 02 Feb 2025 18:22:55 GMT', 'Content-Type': 'application/json', 'Content-Length': '437', 'Connection': 'keep-alive', 'x-amzn-RequestId': '7c6bbfdf-2dcf-44fa-bcbe-f82cfe808066'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"2dcdd920-4976-4c14-80de-bf34aa2dab0b","invocationArn":"arn:aws:bedrock:us-east-1:430118855470:async-invoke/qbzshyxunrgm","lastModifiedTime":"2025-02-02T18:22:53Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm"}},"status":"InProgress","submitTime":"2025-02-02T18:22:53Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB2751940>
# [DEBUG] No retry needed.
# [INFO] Job qbzshyxunrgm is still in progress, elapsed time: 0 minutes 2 seconds
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002BEA2D8F9C0>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002BEA2DB2520>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002BEA2D8F560>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002BEA2DB2480>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002BEA2DB14E0>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB24F7B60>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB24F7A10>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A430118855470%253Aasync-invoke%252Fqbzshyxunrgm
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250202T182305Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182305Z
# 20250202/us-east-1/bedrock/aws4_request
# 1ae00f6cabf617e2d170def4c37a8d78191ea3e0c0dfe9cf1b35b6bfa1ea6e18
# [DEBUG] Signature:
# 6b3607fe94d0c7e2e512e13d1deced4516be6b9466f497ec964c0f62a5f0f72e
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A430118855470%3Aasync-invoke%2Fqbzshyxunrgm, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182305Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=6b3607fe94d0c7e2e512e13d1deced4516be6b9466f497ec964c0f62a5f0f72e', 'amz-sdk-invocation-id': b'09e53056-db46-479e-86a6-a5cd6de69558', 'amz-sdk-request': b'attempt=1'}>
# ...
# [DEBUG] Making request for OperationModel(name=GetObject) with params: {'url_path': '/qbzshyxunrgm/output.mp4', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'auth_path': '/bedrock-video-generation-us-east-1-ip1n64/qbzshyxunrgm/output.mp4', 'url': 'https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com/qbzshyxunrgm/output.mp4', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002BEB2EF7610>, 'has_streaming_input': False, 'auth_type': 'v4', 'unsigned_payload': None, 's3_redirect': {'redirected': False, 'bucket': 'bedrock-video-generation-us-east-1-ip1n64', 'params': {'Bucket': 'bedrock-video-generation-us-east-1-ip1n64', 'Key': 'qbzshyxunrgm/output.mp4', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'bedrock-video-generation-us-east-1-ip1n64', 'Key': 'qbzshyxunrgm/output.mp4'}, 'signing': {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# [DEBUG] Event request-created.s3.GetObject: calling handler <function signal_not_transferring at 0x000002BEB3FD1260>
# [DEBUG] Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002BEB2EF74D0>>
# [DEBUG] Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x000002BEB2BFDE50>>
# [DEBUG] Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x000002BEA2D8F7E0>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x000002BEA2DB1EE0>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x000002BEA2DB25C0>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <botocore.utils.S3ExpressIdentityResolver object at 0x000002BEB3FC9FD0>>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /qbzshyxunrgm/output.mp4
#
# host:bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com
# x-amz-checksum-mode:ENABLED
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20250202T182732Z
#
# host;x-amz-checksum-mode;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250202T182732Z
# 20250202/us-east-1/s3/aws4_request
# cfb4c24ef10a8eb321741dd4ce01df054bd947331c01b5597995ddca112639e1
# [DEBUG] Signature:
# bccb89b058f44994bec332e077a7bc12b23e83352801c9de277de7285ceaa3ce
# [DEBUG] Event request-created.s3.GetObject: calling handler <function signal_transferring at 0x000002BEB3FD1440>
# [DEBUG] Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x000002BEA2DB1D00>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com/qbzshyxunrgm/output.mp4, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250202T182732Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWIJIU4MXGVG3ZS6B/20250202/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-checksum-mode;x-amz-content-sha256;x-amz-date, Signature=bccb89b058f44994bec332e077a7bc12b23e83352801c9de277de7285ceaa3ce', 'amz-sdk-invocation-id': b'b6a73e3d-dbfa-409e-92f0-1e701b5946cb', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-video-generation-us-east-1-ip1n64.s3.amazonaws.com:443 "GET /qbzshyxunrgm/output.mp4 HTTP/1.1" 200 5875570
# [DEBUG] Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x000002BEA2DB22A0>
# [DEBUG] Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x000002BEA2DB20C0>
# [DEBUG] Response headers: {'x-amz-id-2': 'qnMKHHVTk/VSPCCYppozS4bV9MhS+nC7Jg4q4oiQsbLTrQo6WYtqez6wEihjghk3eFxbSuptKxeDQv+rhO9YeKCRY4Tt7jnz', 'x-amz-request-id': 'HXH0PHW8X2D86WB5', 'Date': 'Sun, 02 Feb 2025 18:27:32 GMT', 'Last-Modified': 'Sun, 02 Feb 2025 18:26:26 GMT', 'ETag': '"f3dc1e2df345e14c9b6efd98b03a0e4f"', 'x-amz-checksum-sha256': 'nfP69dJSN2Bf3I1FS7YtFYS6nCgi4K7CGBnJCdaH5ro=', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-meta-content-source': 'AmazonBedrock', 'x-amz-meta-content-additional-params': 'requestId="c6264e3e-0e8d-44a6-9a69-f3aac8ee838b", signedContentSHA384="MGUCMD2bwkfglhy8dHbOa9nQGKNqgVvdsDtJLXI9CWghICaqswxOUjjrcmolKuuhAcWqGAIxAOqxi9jTkc2Zg4p2DqSagYzBTGkGZnjAItWaqwi7Vy7dpJcWRkEPKHL3z3KPdPLs0gAAAAAAAAAB"', 'x-amz-meta-content-model-id': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0', 'Accept-Ranges': 'bytes', 'Content-Type': 'application/octet-stream', 'Content-Length': '5875570', 'Server': 'AmazonS3'}
# [DEBUG] Response body:
# <botocore.httpchecksum.StreamingChecksumBody object at 0x000002BEB3F0E890>
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x000002BEA2DB23E0>
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x000002BEB3F14550>
# [DEBUG] No retry needed.
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.redirect_from_error of <botocore.utils.S3RegionRedirectorv2 object at 0x000002BEB3FC9E80>>
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 0}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 0}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 0}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 0}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 262144}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 262144}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 262144}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 262144}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 524288}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 524288}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 524288}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 524288}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 786432}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 786432}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 786432}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 786432}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1048576}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1048576}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1048576}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 1048576}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1310720}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1310720}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1310720}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 1310720}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1572864}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1572864}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1572864}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 1572864}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1835008}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1835008}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1835008}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 1835008}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2097152}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2097152}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 2097152}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 2097152}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2359296}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2359296}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 2359296}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 2359296}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2621440}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2621440}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 2621440}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 2621440}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2883584}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2883584}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 2883584}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 2883584}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3145728}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3145728}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 3145728}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 3145728}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3407872}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3407872}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 3407872}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 3407872}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3670016}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3670016}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 3670016}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 3670016}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3932160}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 3932160}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 3932160}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 3932160}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4194304}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4194304}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 4194304}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 4194304}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4456448}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4456448}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 4456448}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 4456448}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4718592}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4718592}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 4718592}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 4718592}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4980736}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 4980736}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 4980736}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 4980736}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5242880}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5242880}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 5242880}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 5242880}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5505024}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5505024}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 5505024}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 5505024}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5767168}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 5767168}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 5767168}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'offset': 5767168}
# [DEBUG] IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-02_19-22-53_qbzshyxunrgm\\qbzshyxunrgm.mp4'}) about to wait for the following futures []
# [DEBUG] IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-02_19-22-53_qbzshyxunrgm\\qbzshyxunrgm.mp4'}) done waiting for dependent futures
# [DEBUG] Executing task IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-02_19-22-53_qbzshyxunrgm\\qbzshyxunrgm.mp4'}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002BEB3F17C50>, 'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-02_19-22-53_qbzshyxunrgm\\qbzshyxunrgm.mp4', 'osutil': <s3transfer.utils.OSUtils object at 0x000002BEB3F14F50>}
# [DEBUG] Releasing acquire 0/None
# [INFO] Downloaded video file: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-02_19-22-53_qbzshyxunrgm\qbzshyxunrgm.mp4
# [INFO] Saved completed job details to c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-02_19-22-53_qbzshyxunrgm\completed.json
# [INFO]
# Video successfully generated and downloaded to: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-02_19-22-53_qbzshyxunrgm\qbzshyxunrgm.mp4
