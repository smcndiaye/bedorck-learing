# %%
import boto3
import logging
import json
import random
import amazon_video_util
from datetime import datetime, timedelta, timezone

# Configure logging
logging.basicConfig(level=logging.DEBUG, format='[%(levelname)s] %(message)s')
logger = logging.getLogger(__name__)

# %%
logging.basicConfig(level=logging.DEBUG, format='[%(levelname)s] %(message)s')
logger = logging.getLogger(__name__)

# Constants
DEFAULT_MODEL_ID = "amazon.nova-reel-v1:0"

def setup_aws_session(region="us-east-1"):
    """Set up AWS session with default region"""
    boto3.setup_default_session(region_name=region)
    logger.info("AWS SDK session defaults have been set.")


def generate_video(s3_destination_bucket, video_prompt, model_id=DEFAULT_MODEL_ID):
    """
    Generate a video using the provided prompt.
    
    Args:
        s3_destination_bucket (str): The S3 bucket where the video will be stored
        video_prompt (str): Text prompt describing the desired video
    """
    # Set up the S3 client
    s3_client = boto3.client("s3")

    # Create the S3 bucket
    s3_client.create_bucket(Bucket=s3_destination_bucket)

    # Create the Bedrock Runtime client
    bedrock_runtime = boto3.client("bedrock-runtime")

    model_input = {
        "taskType": "TEXT_VIDEO",
        "textToVideoParams": {
            "text": video_prompt,
        },
        "videoGenerationConfig": {
            "durationSeconds": 6,  # 6 is the only supported value currently
            "fps": 24,  # 24 is the only supported value currently
            "dimension": "1280x720",  # "1280x720" is the only supported value currently
            "seed": random.randint(
                0, 2147483648
            ),  # A random seed guarantees we'll get a different result each time this code runs
        },
    }

    try:
        # Start the asynchronous video generation job
        invocation = bedrock_runtime.start_async_invoke(
            modelId=model_id,
            modelInput=model_input,
            outputDataConfig={"s3OutputDataConfig": {"s3Uri": f"s3://{s3_destination_bucket}"}},
        )

        # Store the invocation ARN
        invocation_arn = invocation["invocationArn"]

        # Pretty print the response JSON
        logger.info("\nResponse:")
        logger.info(json.dumps(invocation, indent=2, default=str))

        # Save the invocation details for later reference
        amazon_video_util.save_invocation_info(invocation, model_input)

        return invocation_arn

    except Exception as e:
        logger.error(e)
        return None

def check_job_status(invocation_arn):
    """Check status of a specific job using get_async_invoke()"""
    bedrock_runtime = boto3.client("bedrock-runtime")
    try:
        response = bedrock_runtime.get_async_invoke(
            invocationArn=invocation_arn
        )
        
        status = response["status"]
        logger.info(f"Status: {status}")
        logger.info("\nFull response:")
        logger.info(json.dumps(response, indent=2, default=str))
        return response
    except Exception as e:
        logger.error(f"Error checking job status: {e}")
        return None

def list_job_statuses(max_results=10, status_filter="InProgress"):
    """List all video generation jobs with optional filtering"""
    bedrock_runtime = boto3.client("bedrock-runtime")
    try:
        invocation = bedrock_runtime.list_async_invokes(
            maxResults=max_results,
            statusEquals=status_filter,
        )
        
        logger.info("Invocation Jobs:")
        logger.info(json.dumps(invocation, indent=2, default=str))
        return invocation
    except Exception as e:
        logger.error(f"Error listing jobs: {e}")
        return None

def monitor_recent_jobs(duration_hours=1):
    """Monitor and download videos from the past N hours"""
    from_submit_time = datetime.now(timezone.utc) - timedelta(hours=duration_hours)
    return amazon_video_util.monitor_and_download_videos("output", submit_time_after=from_submit_time)


def main():
    # Initialize the AWS session
    setup_aws_session()

    # Configuration
    S3_BUCKET = "bedrock-kb-us-east-1-448049799059"  # Change this to your unique bucket name
    VIDEO_PROMPT = " 2 people takking cofee"
    MODEL_ID = "amazon.nova-reel-v1:0"

    # Generate video
    invocation_arn = generate_video(S3_BUCKET, VIDEO_PROMPT, MODEL_ID)
    if not invocation_arn:
        logger.error("Failed to start video generation")
        exit(1)

    # Check initial status
    logger.info("\nChecking initial job status...")
    check_job_status(invocation_arn)

    # List all in-progress jobs
    logger.info("\nListing all in-progress jobs...")
    list_job_statuses()

    # Monitor and download the video
    logger.info("\nMonitoring job and waiting for completion...")
    local_file_path = amazon_video_util.monitor_and_download_video(invocation_arn, "output")

    if local_file_path:
        logger.info(f"\nVideo successfully generated and downloaded to: {local_file_path}")
    else:
        logger.info("\nFailed to generate or download video")

if __name__ == "__main__":
    main()
# Out:
# [DEBUG] Changing event name from creating-client-class.iot-data to creating-client-class.iot-data-plane
# [DEBUG] Changing event name from before-call.apigateway to before-call.api-gateway
# [DEBUG] Changing event name from request-created.machinelearning.Predict to request-created.machine-learning.Predict
# [DEBUG] Changing event name from before-parameter-build.autoscaling.CreateLaunchConfiguration to before-parameter-build.auto-scaling.CreateLaunchConfiguration
# [DEBUG] Changing event name from before-parameter-build.route53 to before-parameter-build.route-53
# [DEBUG] Changing event name from request-created.cloudsearchdomain.Search to request-created.cloudsearch-domain.Search
# [DEBUG] Changing event name from docs.*.autoscaling.CreateLaunchConfiguration.complete-section to docs.*.auto-scaling.CreateLaunchConfiguration.complete-section
# [DEBUG] Changing event name from before-parameter-build.logs.CreateExportTask to before-parameter-build.cloudwatch-logs.CreateExportTask
# [DEBUG] Changing event name from docs.*.logs.CreateExportTask.complete-section to docs.*.cloudwatch-logs.CreateExportTask.complete-section
# [DEBUG] Changing event name from before-parameter-build.cloudsearchdomain.Search to before-parameter-build.cloudsearch-domain.Search
# [DEBUG] Changing event name from docs.*.cloudsearchdomain.Search.complete-section to docs.*.cloudsearch-domain.Search.complete-section
# [DEBUG] Setting config variable for region to 'us-east-1'
# [INFO] AWS SDK session defaults have been set.
# [DEBUG] IMDS ENDPOINT: http://169.254.169.254/
# [DEBUG] Looking for credentials via: env
# [DEBUG] Looking for credentials via: assume-role
# [DEBUG] Looking for credentials via: assume-role-with-web-identity
# [DEBUG] Looking for credentials via: sso
# [DEBUG] Looking for credentials via: shared-credentials-file
# [INFO] Found credentials in shared credentials file: ~/.aws/credentials
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\endpoints.json
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\sdk-default-configuration.json
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002183BF4F420>
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\service-2.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\service-2.sdk-extras.json
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\s3\2006-03-01\endpoint-rule-set-1.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\partitions.json
# [DEBUG] Event creating-client-class.s3: calling handler <function add_generate_presigned_post at 0x000002183BEC8A40>
# [DEBUG] Event creating-client-class.s3: calling handler <function lazy_call.<locals>._handler at 0x000002184DD15580>
# [DEBUG] Event creating-client-class.s3: calling handler <function add_generate_presigned_url at 0x000002183BEC87C0>
# [DEBUG] Looking for endpoint for s3 via: environment_service
# [DEBUG] Looking for endpoint for s3 via: environment_global
# [DEBUG] Looking for endpoint for s3 via: config_service
# [DEBUG] Looking for endpoint for s3 via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Setting s3 timeout as (60, 60)
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\_retry.json
# [DEBUG] Registering retry handlers for service: s3
# [DEBUG] Registering S3 region redirector handler
# [DEBUG] Registering S3Express Identity Resolver
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function validate_bucket_name at 0x000002183BF4FC40>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function remove_bucket_from_url_paths_from_model at 0x000002183BF6DE40>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184DD8F890>>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <bound method ClientCreator._inject_s3_input_parameters of <botocore.client.ClientCreator object at 0x000002184DDA42B0>>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.s3.CreateBucket: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x000002183BF6E020>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184DD8F890>>
# [DEBUG] Calling endpoint provider with parameters: {'Bucket': 'bedrock-kb-us-east-1-448049799059', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'DisableAccessPoints': True, 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True, 'UseS3ExpressControlEndpoint': True}
# [DEBUG] Endpoint provider result: https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com
# [DEBUG] Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "None"
# [DEBUG] Selected auth type "v4" as "v4" with signing context params: {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_expect_header at 0x000002183BF6C040>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <botocore.utils.S3ExpressIdentityResolver object at 0x000002184DD8F9D0>>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.s3.CreateBucket: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=CreateBucket) with params: {'url_path': '', 'query_string': {}, 'method': 'PUT', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'auth_path': '/bedrock-kb-us-east-1-448049799059/', 'url': 'https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com/', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184DD8F610>, 'has_streaming_input': False, 'auth_type': 'v4', 'unsigned_payload': None, 's3_redirect': {'redirected': False, 'bucket': 'bedrock-kb-us-east-1-448049799059', 'params': {'Bucket': 'bedrock-kb-us-east-1-448049799059'}}, 'input_params': {'Bucket': 'bedrock-kb-us-east-1-448049799059'}, 'signing': {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}}}
# [DEBUG] Event request-created.s3.CreateBucket: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184DDA6D70>>
# [DEBUG] Event choose-signer.s3.CreateBucket: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x000002184DDA42B0>>
# [DEBUG] Event choose-signer.s3.CreateBucket: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <function remove_arn_from_signing_path at 0x000002183BF6DF80>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <function _set_extra_headers_for_unsigned_request at 0x000002183BF6E660>
# [DEBUG] Event before-sign.s3.CreateBucket: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <botocore.utils.S3ExpressIdentityResolver object at 0x000002184DD8F9D0>>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# PUT
# /
#
# host:bedrock-kb-us-east-1-448049799059.s3.amazonaws.com
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20250206T171142Z
#
# host;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171142Z
# 20250206/us-east-1/s3/aws4_request
# cc172a089c8fbf3ea5ce372a70f7a4cb56f1790db6e7fe005e8f3117a75299cc
# [DEBUG] Signature:
# 50812cc93147e1b18436c008f6121bd8115bc30229a92c108c132ceeaca40277
# [DEBUG] Event request-created.s3.CreateBucket: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=PUT, url=https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com/, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171142Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-content-sha256;x-amz-date, Signature=50812cc93147e1b18436c008f6121bd8115bc30229a92c108c132ceeaca40277', 'amz-sdk-invocation-id': b'eed8070e-aa8d-4ab8-92b1-e665e82f2d1f', 'amz-sdk-request': b'attempt=1', 'Content-Length': '0'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-kb-us-east-1-448049799059.s3.amazonaws.com:443
# [DEBUG] https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com:443 "PUT / HTTP/1.1" 200 0
# [DEBUG] Event before-parse.s3.CreateBucket: calling handler <function _handle_200_error at 0x000002183BF6E340>
# [DEBUG] Event before-parse.s3.CreateBucket: calling handler <function handle_expires_header at 0x000002183BF6E160>
# [DEBUG] Response headers: {'x-amz-id-2': 't1BRuFcjy8vuWxNizIr7zmF36gZiX2jijfav3A5A5K+uD88Bc6Lold5GiWM0IL40OGUViTUxqqmmMYraUDgTvw==', 'x-amz-request-id': '4S7GQVM1K1BD3KBA', 'Date': 'Thu, 06 Feb 2025 17:11:44 GMT', 'Location': '/bedrock-kb-us-east-1-448049799059', 'Content-Length': '0', 'Server': 'AmazonS3'}
# [DEBUG] Response body:
# b''
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <function _update_status_code at 0x000002183BF6E480>
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184DDA7E10>
# [DEBUG] No retry needed.
# [DEBUG] Event needs-retry.s3.CreateBucket: calling handler <bound method S3RegionRedirectorv2.redirect_from_error of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184DD8F890>>
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002183BF4F420>
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\bedrock-runtime\2023-09-30\service-2.json.gz
# [DEBUG] Loading JSON file: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\botocore\data\bedrock-runtime\2023-09-30\endpoint-rule-set-1.json.gz
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002183BEC87C0>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.StartAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] injecting idempotency token (0703477e-78ef-4c77-9b4b-c1533e531e69) into param 'clientRequestToken'.
# [DEBUG] Event before-parameter-build.bedrock-runtime.StartAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.StartAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=StartAsyncInvoke) with params: {'url_path': '/async-invoke', 'query_string': {}, 'method': 'POST', 'headers': {'Content-Type': 'application/json', 'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'{"modelId": "amazon.nova-reel-v1:0", "modelInput": {"taskType": "TEXT_VIDEO", "textToVideoParams": {"text": "4 kids writing their homework at the thir classroom"}, "videoGenerationConfig": {"durationSeconds": 6, "fps": 24, "dimension": "1280x720", "seed": 2029781099}}, "outputDataConfig": {"s3OutputDataConfig": {"s3Uri": "s3://bedrock-kb-us-east-1-448049799059"}}, "clientRequestToken": "0703477e-78ef-4c77-9b4b-c1533e531e69"}', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184E6E0690>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.StartAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184DDA6B10>>
# [DEBUG] Event choose-signer.bedrock-runtime.StartAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# POST
# /async-invoke
#
# content-type:application/json
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171143Z
#
# content-type;host;x-amz-date
# a4aedc8b47edce724390a0c81604cc337756cad49eb2a5a7e6a2c28f6060a799
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171143Z
# 20250206/us-east-1/bedrock/aws4_request
# 04e2d56507d81b1c8612df3f8ac7a55d3e7055b8c15ceb9777950679f373a535
# [DEBUG] Signature:
# cdf8d717642e2723557e29db218d3493dfb227eae6e589429d891a3e849d0a93
# [DEBUG] Event request-created.bedrock-runtime.StartAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=POST, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke, headers={'Content-Type': b'application/json', 'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171143Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=content-type;host;x-amz-date, Signature=cdf8d717642e2723557e29db218d3493dfb227eae6e589429d891a3e849d0a93', 'amz-sdk-invocation-id': b'9fa8b78b-c5de-4c8d-9b18-4e498ad8790c', 'amz-sdk-request': b'attempt=1', 'Content-Length': '428'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "POST /async-invoke HTTP/1.1" 200 84
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:44 GMT', 'Content-Type': 'application/json', 'Content-Length': '84', 'Connection': 'keep-alive', 'x-amzn-RequestId': '277fc051-6d33-4df6-bf47-6bffc7bb6568'}
# [DEBUG] Response body:
# b'{"invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k"}'
# [DEBUG] Event needs-retry.bedrock-runtime.StartAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184E6E9940>
# [DEBUG] No retry needed.
# [INFO]
# Response:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "277fc051-6d33-4df6-bf47-6bffc7bb6568",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Thu, 06 Feb 2025 17:11:44 GMT",
#       "content-type": "application/json",
#       "content-length": "84",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "277fc051-6d33-4df6-bf47-6bffc7bb6568"
#     },
#     "RetryAttempts": 0
#   },
#   "invocationArn": "arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k"
# }
# [INFO] Getting async invoke details for ARN: arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184B14A510>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184B14A3C0>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A448049799059%253Aasync-invoke%252Fug5stryadw0k
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171144Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171144Z
# 20250206/us-east-1/bedrock/aws4_request
# 906cfda27949a5b29170ae9b275d685c4cf77d87409dc9dc1ac7fecc98acf908
# [DEBUG] Signature:
# addbda917f52a7ffc8b2d6e97e7aa03b969b0533005e0f03932d135d8d5b8361
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171144Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=addbda917f52a7ffc8b2d6e97e7aa03b969b0533005e0f03932d135d8d5b8361', 'amz-sdk-invocation-id': b'88c436b5-bb01-440b-a131-1b030c623b51', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k HTTP/1.1" 200 429
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:45 GMT', 'Content-Type': 'application/json', 'Content-Length': '429', 'Connection': 'keep-alive', 'x-amzn-RequestId': '61e06d5a-4643-49e1-a823-a4c0c3a2fd4d'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"0703477e-78ef-4c77-9b4b-c1533e531e69","invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k","lastModifiedTime":"2025-02-06T17:11:43Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"}},"status":"InProgress","submitTime":"2025-02-06T17:11:43Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184B3C02F0>
# [DEBUG] No retry needed.
# [INFO] Generated folder name: 2025-02-06_18-11-43_ug5stryadw0k
# [INFO] Saving invocation info to folder: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-06_18-11-43_ug5stryadw0k
# [INFO] Saved start_async_invoke_response.json
# [INFO] Saved model_input.json
# [INFO]
# Checking initial job status...
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002183BF4F420>
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002183BEC87C0>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184DD8F610>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184E789130>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A448049799059%253Aasync-invoke%252Fug5stryadw0k
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171145Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171145Z
# 20250206/us-east-1/bedrock/aws4_request
# b880fcf82c6f37d2346f0411aa3c6f98fb06032a05efcae682671c915b73dac1
# [DEBUG] Signature:
# a2359d90d4b4db6a0743539c64326a43276c73c97d7abcdc623ddd81491394af
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171145Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=a2359d90d4b4db6a0743539c64326a43276c73c97d7abcdc623ddd81491394af', 'amz-sdk-invocation-id': b'95f21e9c-ccb4-4512-a6f5-93bb69dc7bf6', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k HTTP/1.1" 200 429
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:46 GMT', 'Content-Type': 'application/json', 'Content-Length': '429', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'a2034316-b66d-474e-a2dd-cd0cb695a5c2'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"0703477e-78ef-4c77-9b4b-c1533e531e69","invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k","lastModifiedTime":"2025-02-06T17:11:43Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"}},"status":"InProgress","submitTime":"2025-02-06T17:11:43Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184E789D90>
# [DEBUG] No retry needed.
# [INFO] Status: InProgress
# [INFO]
# Full response:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "a2034316-b66d-474e-a2dd-cd0cb695a5c2",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Thu, 06 Feb 2025 17:11:46 GMT",
#       "content-type": "application/json",
#       "content-length": "429",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "a2034316-b66d-474e-a2dd-cd0cb695a5c2"
#     },
#     "RetryAttempts": 0
#   },
#   "invocationArn": "arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k",
#   "modelArn": "arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0",
#   "clientRequestToken": "0703477e-78ef-4c77-9b4b-c1533e531e69",
#   "status": "InProgress",
#   "submitTime": "2025-02-06 17:11:43+00:00",
#   "lastModifiedTime": "2025-02-06 17:11:43+00:00",
#   "outputDataConfig": {
#     "s3OutputDataConfig": {
#       "s3Uri": "s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"
#     }
#   }
# }
# [INFO]
# Listing all in-progress jobs...
# [DEBUG] Event choose-service-name: calling handler <function handle_service_name_alias at 0x000002183BF4F420>
# [DEBUG] Event creating-client-class.bedrock-runtime: calling handler <function add_generate_presigned_url at 0x000002183BEC87C0>
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: environment_global
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_service
# [DEBUG] Looking for endpoint for bedrock-runtime via: config_global
# [DEBUG] No configured endpoint found.
# [DEBUG] Creating a regex based endpoint for bedrock-runtime, us-east-1
# [DEBUG] Setting bedrock-runtime timeout as (60, 60)
# [DEBUG] Registering retry handlers for service: bedrock-runtime
# [DEBUG] Event before-parameter-build.bedrock-runtime.ListAsyncInvokes: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.ListAsyncInvokes: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.ListAsyncInvokes: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=ListAsyncInvokes) with params: {'url_path': '/async-invoke', 'query_string': {'maxResults': 10, 'statusEquals': 'InProgress'}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke?maxResults=10&statusEquals=InProgress', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184DD8F610>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.ListAsyncInvokes: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184DFDA470>>
# [DEBUG] Event choose-signer.bedrock-runtime.ListAsyncInvokes: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke
# maxResults=10&statusEquals=InProgress
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171146Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171146Z
# 20250206/us-east-1/bedrock/aws4_request
# 6df6f597fe712ce7a1d4a81253e4ebf9edb4db73b4a5b8ba903585b664d522bc
# [DEBUG] Signature:
# 2b0d2616514fa5b86f107a465b043c10a5a7891290b94fa9eee7bc4c79ba7b6b
# [DEBUG] Event request-created.bedrock-runtime.ListAsyncInvokes: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke?maxResults=10&statusEquals=InProgress, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171146Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=2b0d2616514fa5b86f107a465b043c10a5a7891290b94fa9eee7bc4c79ba7b6b', 'amz-sdk-invocation-id': b'08243775-c200-46cc-811c-ee49f71bd7ce', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] Starting new HTTPS connection (1): bedrock-runtime.us-east-1.amazonaws.com:443
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke?maxResults=10&statusEquals=InProgress HTTP/1.1" 200 456
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:46 GMT', 'Content-Type': 'application/json', 'Content-Length': '456', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'bced43ce-5f0a-4fba-be27-48c68ebe98b7'}
# [DEBUG] Response body:
# b'{"asyncInvokeSummaries":[{"clientRequestToken":"0703477e-78ef-4c77-9b4b-c1533e531e69","invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k","lastModifiedTime":"2025-02-06T17:11:43Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"}},"status":"InProgress","submitTime":"2025-02-06T17:11:43Z"}]}'
# [DEBUG] Event needs-retry.bedrock-runtime.ListAsyncInvokes: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184DFDB130>
# [DEBUG] No retry needed.
# [INFO] Invocation Jobs:
# [INFO] {
#   "ResponseMetadata": {
#     "RequestId": "bced43ce-5f0a-4fba-be27-48c68ebe98b7",
#     "HTTPStatusCode": 200,
#     "HTTPHeaders": {
#       "date": "Thu, 06 Feb 2025 17:11:46 GMT",
#       "content-type": "application/json",
#       "content-length": "456",
#       "connection": "keep-alive",
#       "x-amzn-requestid": "bced43ce-5f0a-4fba-be27-48c68ebe98b7"
#     },
#     "RetryAttempts": 0
#   },
#   "asyncInvokeSummaries": [
#     {
#       "invocationArn": "arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k",
#       "modelArn": "arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0",
#       "clientRequestToken": "0703477e-78ef-4c77-9b4b-c1533e531e69",
#       "status": "InProgress",
#       "submitTime": "2025-02-06 17:11:43+00:00",
#       "lastModifiedTime": "2025-02-06 17:11:43+00:00",
#       "outputDataConfig": {
#         "s3OutputDataConfig": {
#           "s3Uri": "s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"
#         }
#       }
#     }
#   ]
# }
# [INFO]
# Monitoring job and waiting for completion...
# [INFO] Monitoring and downloading video for ARN: arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184B14A510>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184B14A3C0>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A448049799059%253Aasync-invoke%252Fug5stryadw0k
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171147Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171147Z
# 20250206/us-east-1/bedrock/aws4_request
# b15c0887253dd2c5f47f782b2047edb7b0b619581da6ccfa71bab79205031fb4
# [DEBUG] Signature:
# 6125ca966fb3eee43df1425767ed7b262f27d5af074e5c76c9d10cfffad00375
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171147Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=6125ca966fb3eee43df1425767ed7b262f27d5af074e5c76c9d10cfffad00375', 'amz-sdk-invocation-id': b'0973efc7-de58-475b-9dfa-ab3c12ba9ed1', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k HTTP/1.1" 200 429
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:47 GMT', 'Content-Type': 'application/json', 'Content-Length': '429', 'Connection': 'keep-alive', 'x-amzn-RequestId': '89906f27-101c-4331-aadd-63f5f3a20e16'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"0703477e-78ef-4c77-9b4b-c1533e531e69","invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k","lastModifiedTime":"2025-02-06T17:11:43Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"}},"status":"InProgress","submitTime":"2025-02-06T17:11:43Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184B3C02F0>
# [DEBUG] No retry needed.
# [INFO] Monitoring and downloading in-progress video for ARN: arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184B14A510>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184B14A3C0>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A448049799059%253Aasync-invoke%252Fug5stryadw0k
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171147Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171147Z
# 20250206/us-east-1/bedrock/aws4_request
# b15c0887253dd2c5f47f782b2047edb7b0b619581da6ccfa71bab79205031fb4
# [DEBUG] Signature:
# 6125ca966fb3eee43df1425767ed7b262f27d5af074e5c76c9d10cfffad00375
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171147Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=6125ca966fb3eee43df1425767ed7b262f27d5af074e5c76c9d10cfffad00375', 'amz-sdk-invocation-id': b'adeac203-6376-4d89-93ab-24468246073f', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-runtime.us-east-1.amazonaws.com:443 "GET /async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k HTTP/1.1" 200 429
# [DEBUG] Response headers: {'Date': 'Thu, 06 Feb 2025 17:11:47 GMT', 'Content-Type': 'application/json', 'Content-Length': '429', 'Connection': 'keep-alive', 'x-amzn-RequestId': 'df61b4a3-51d7-4a9f-a31b-79d2bd0bc3a6'}
# [DEBUG] Response body:
# b'{"clientRequestToken":"0703477e-78ef-4c77-9b4b-c1533e531e69","invocationArn":"arn:aws:bedrock:us-east-1:448049799059:async-invoke/ug5stryadw0k","lastModifiedTime":"2025-02-06T17:11:43Z","modelArn":"arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0","outputDataConfig":{"s3OutputDataConfig":{"s3Uri":"s3://bedrock-kb-us-east-1-448049799059/ug5stryadw0k"}},"status":"InProgress","submitTime":"2025-02-06T17:11:43Z"}'
# [DEBUG] Event needs-retry.bedrock-runtime.GetAsyncInvoke: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184B3C02F0>
# [DEBUG] No retry needed.
# [INFO] Job ug5stryadw0k is still in progress, elapsed time: 0 minutes 4 seconds
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.bedrock-runtime.GetAsyncInvoke: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Calling endpoint provider with parameters: {'Region': 'us-east-1', 'UseDualStack': False, 'UseFIPS': False}
# [DEBUG] Endpoint provider result: https://bedrock-runtime.us-east-1.amazonaws.com
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.bedrock-runtime.GetAsyncInvoke: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetAsyncInvoke) with params: {'url_path': '/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'query_string': {}, 'method': 'GET', 'headers': {'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'url': 'https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184B14A510>, 'has_streaming_input': False, 'auth_type': None, 'unsigned_payload': None}}
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184B14A3C0>>
# [DEBUG] Event choose-signer.bedrock-runtime.GetAsyncInvoke: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /async-invoke/arn%253Aaws%253Abedrock%253Aus-east-1%253A448049799059%253Aasync-invoke%252Fug5stryadw0k
#
# host:bedrock-runtime.us-east-1.amazonaws.com
# x-amz-date:20250206T171157Z
#
# host;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171157Z
# 20250206/us-east-1/bedrock/aws4_request
# 5b7752f777622cb2e9f2e1f0e00f98bea37d6ecf43aa0c8fd3806eb6cdecfac5
# [DEBUG] Signature:
# 8816ed319ffd7bcdefa6ff99af0a9c70712df89961419623ce42e05bd40b22dc
# [DEBUG] Event request-created.bedrock-runtime.GetAsyncInvoke: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=False, method=GET, url=https://bedrock-runtime.us-east-1.amazonaws.com/async-invoke/arn%3Aaws%3Abedrock%3Aus-east-1%3A448049799059%3Aasync-invoke%2Fug5stryadw0k, headers={'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171157Z', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/bedrock/aws4_request, SignedHeaders=host;x-amz-date, Signature=8816ed319ffd7bcdefa6ff99af0a9c70712df89961419623ce42e05bd40b22dc', 'amz-sdk-invocation-id': b'bbfbb083-0e87-4b00-903e-1aadb7f22df8', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# ...
# [DEBUG] Response body:
# b''
# [DEBUG] Event needs-retry.s3.HeadObject: calling handler <function _update_status_code at 0x000002183BF6E480>
# [DEBUG] Event needs-retry.s3.HeadObject: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184CC28F50>
# [DEBUG] No retry needed.
# [DEBUG] Event needs-retry.s3.HeadObject: calling handler <bound method S3RegionRedirectorv2.redirect_from_error of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184BB7C830>>
# [DEBUG] Submitting task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'bedrock-kb-us-east-1-448049799059', 'key': 'ug5stryadw0k/output.mp4', 'extra_args': {}}) to executor <s3transfer.futures.BoundedExecutor object at 0x000002184E78C2F0> for transfer request: 0.
# [DEBUG] Acquiring 0
# [DEBUG] ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'bedrock-kb-us-east-1-448049799059', 'key': 'ug5stryadw0k/output.mp4', 'extra_args': {}}) about to wait for the following futures []
# [DEBUG] Releasing acquire 0/None
# [DEBUG] ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'bedrock-kb-us-east-1-448049799059', 'key': 'ug5stryadw0k/output.mp4', 'extra_args': {}}) done waiting for dependent futures
# [DEBUG] Executing task ImmediatelyWriteIOGetObjectTask(transfer_id=0, {'bucket': 'bedrock-kb-us-east-1-448049799059', 'key': 'ug5stryadw0k/output.mp4', 'extra_args': {}}) with kwargs {'client': <botocore.client.S3 object at 0x000002184BB7C6E0>, 'bucket': 'bedrock-kb-us-east-1-448049799059', 'key': 'ug5stryadw0k/output.mp4', 'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'extra_args': {}, 'callbacks': [], 'max_attempts': 5, 'download_output_manager': <s3transfer.download.DownloadFilenameOutputManager object at 0x000002184E78CEC0>, 'io_chunksize': 262144, 'bandwidth_limiter': None}
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <function sse_md5 at 0x000002183BF4FCE0>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <function validate_bucket_name at 0x000002183BF4FC40>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <function remove_bucket_from_url_paths_from_model at 0x000002183BF6DE40>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.annotate_request_context of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184BB7C830>>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <bound method ClientCreator._inject_s3_input_parameters of <botocore.client.ClientCreator object at 0x000002184B14E850>>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <function generate_idempotent_uuid at 0x000002183BF4FA60>
# [DEBUG] Event before-parameter-build.s3.GetObject: calling handler <function _handle_request_validation_mode_member at 0x000002183BF6E5C0>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <function customize_endpoint_resolver_builtins at 0x000002183BF6E020>
# [DEBUG] Event before-endpoint-resolution.s3: calling handler <bound method S3RegionRedirectorv2.redirect_from_cache of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184BB7C830>>
# [DEBUG] Calling endpoint provider with parameters: {'Bucket': 'bedrock-kb-us-east-1-448049799059', 'Region': 'us-east-1', 'UseFIPS': False, 'UseDualStack': False, 'ForcePathStyle': False, 'Accelerate': False, 'UseGlobalEndpoint': True, 'Key': 'ug5stryadw0k/output.mp4', 'DisableMultiRegionAccessPoints': False, 'UseArnRegion': True}
# [DEBUG] Endpoint provider result: https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com
# [DEBUG] Selecting from endpoint provider's list of auth schemes: "sigv4". User selected auth scheme is: "None"
# [DEBUG] Selected auth type "v4" as "v4" with signing context params: {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}
# [DEBUG] Event before-call.s3.GetObject: calling handler <function add_expect_header at 0x000002183BF6C040>
# [DEBUG] Event before-call.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.apply_signing_cache_key of <botocore.utils.S3ExpressIdentityResolver object at 0x000002184BB7C980>>
# [DEBUG] Event before-call.s3.GetObject: calling handler <function add_recursion_detection_header at 0x000002183BF4F600>
# [DEBUG] Event before-call.s3.GetObject: calling handler <function add_query_compatibility_header at 0x000002183BF6E520>
# [DEBUG] Event before-call.s3.GetObject: calling handler <function inject_api_version_header_if_needed at 0x000002183BF6D580>
# [DEBUG] Making request for OperationModel(name=GetObject) with params: {'url_path': '/ug5stryadw0k/output.mp4', 'query_string': {}, 'method': 'GET', 'headers': {'x-amz-checksum-mode': 'ENABLED', 'User-Agent': 'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6'}, 'body': b'', 'auth_path': '/bedrock-kb-us-east-1-448049799059/ug5stryadw0k/output.mp4', 'url': 'https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com/ug5stryadw0k/output.mp4', 'context': {'client_region': 'us-east-1', 'client_config': <botocore.config.Config object at 0x000002184CC28050>, 'has_streaming_input': False, 'auth_type': 'v4', 'unsigned_payload': None, 's3_redirect': {'redirected': False, 'bucket': 'bedrock-kb-us-east-1-448049799059', 'params': {'Bucket': 'bedrock-kb-us-east-1-448049799059', 'Key': 'ug5stryadw0k/output.mp4', 'ChecksumMode': 'ENABLED'}}, 'input_params': {'Bucket': 'bedrock-kb-us-east-1-448049799059', 'Key': 'ug5stryadw0k/output.mp4'}, 'signing': {'region': 'us-east-1', 'signing_name': 's3', 'disableDoubleEncoding': True}, 'endpoint_properties': {'authSchemes': [{'disableDoubleEncoding': True, 'name': 'sigv4', 'signingName': 's3', 'signingRegion': 'us-east-1'}]}, 'checksum': {'response_algorithms': ['crc32', 'sha1', 'sha256']}}}
# [DEBUG] Event request-created.s3.GetObject: calling handler <function signal_not_transferring at 0x000002184BC11E40>
# [DEBUG] Event request-created.s3.GetObject: calling handler <bound method RequestSigner.handler of <botocore.signers.RequestSigner object at 0x000002184BAEBED0>>
# [DEBUG] Event choose-signer.s3.GetObject: calling handler <bound method ClientCreator._default_s3_presign_to_sigv2 of <botocore.client.ClientCreator object at 0x000002184B14E850>>
# [DEBUG] Event choose-signer.s3.GetObject: calling handler <function set_operation_specific_signer at 0x000002183BF4F880>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <function remove_arn_from_signing_path at 0x000002183BF6DF80>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <function _set_extra_headers_for_unsigned_request at 0x000002183BF6E660>
# [DEBUG] Event before-sign.s3.GetObject: calling handler <bound method S3ExpressIdentityResolver.resolve_s3express_identity of <botocore.utils.S3ExpressIdentityResolver object at 0x000002184BB7C980>>
# [DEBUG] Calculating signature using v4 auth.
# [DEBUG] CanonicalRequest:
# GET
# /ug5stryadw0k/output.mp4
#
# host:bedrock-kb-us-east-1-448049799059.s3.amazonaws.com
# x-amz-checksum-mode:ENABLED
# x-amz-content-sha256:e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# x-amz-date:20250206T171533Z
#
# host;x-amz-checksum-mode;x-amz-content-sha256;x-amz-date
# e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855
# [DEBUG] StringToSign:
# AWS4-HMAC-SHA256
# 20250206T171533Z
# 20250206/us-east-1/s3/aws4_request
# 46ba9bd337a1dcd6b70b5be28796972eda3a4bda84829c6209605833dab23b6d
# [DEBUG] Signature:
# 249446a3cdb052f96030f9179fd83344b00a8460411f1130a0def279a8860b19
# [DEBUG] Event request-created.s3.GetObject: calling handler <function signal_transferring at 0x000002184BC12020>
# [DEBUG] Event request-created.s3.GetObject: calling handler <function add_retry_headers at 0x000002183BF6DDA0>
# [DEBUG] Sending http request: <AWSPreparedRequest stream_output=True, method=GET, url=https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com/ug5stryadw0k/output.mp4, headers={'x-amz-checksum-mode': b'ENABLED', 'User-Agent': b'Boto3/1.36.6 md/Botocore#1.36.6 ua/2.0 os/windows#10 md/arch#amd64 lang/python#3.13.1 md/pyimpl#CPython cfg/retry-mode#legacy Botocore/1.36.6', 'X-Amz-Date': b'20250206T171533Z', 'X-Amz-Content-SHA256': b'e3b0c44298fc1c149afbf4c8996fb92427ae41e4649b934ca495991b7852b855', 'Authorization': b'AWS4-HMAC-SHA256 Credential=AKIAWQUOZL6JRNV7BA6O/20250206/us-east-1/s3/aws4_request, SignedHeaders=host;x-amz-checksum-mode;x-amz-content-sha256;x-amz-date, Signature=249446a3cdb052f96030f9179fd83344b00a8460411f1130a0def279a8860b19', 'amz-sdk-invocation-id': b'dd743dcb-5c91-49af-a94f-3e6670ce67e5', 'amz-sdk-request': b'attempt=1'}>
# [DEBUG] Certificate path: c:\Users\mouhand\Documents\Python\bedrock\br\Lib\site-packages\certifi\cacert.pem
# [DEBUG] https://bedrock-kb-us-east-1-448049799059.s3.amazonaws.com:443 "GET /ug5stryadw0k/output.mp4 HTTP/1.1" 200 2307172
# [DEBUG] Event before-parse.s3.GetObject: calling handler <function _handle_200_error at 0x000002183BF6E340>
# [DEBUG] Event before-parse.s3.GetObject: calling handler <function handle_expires_header at 0x000002183BF6E160>
# [DEBUG] Response headers: {'x-amz-id-2': '3Vm3LjUT3zchHQwEznuG1IMSh2XVd+nN/kmiW4atPXBgKcHWVk1MNc8lLa5hj91BWx95vhx4+ifPJkf5zAzGTZvsPiv8jzIhCFJskwTuvmQ=', 'x-amz-request-id': 'RZ91Y8WPRHNP94AF', 'Date': 'Thu, 06 Feb 2025 17:15:34 GMT', 'Last-Modified': 'Thu, 06 Feb 2025 17:15:16 GMT', 'ETag': '"9c64441a9e0e0fdc13eae3d7d5afd4dc"', 'x-amz-checksum-sha256': 'sSSahDAy1sQnupHeAl7QbPLhSTy3ie081Jy4OSvbmAw=', 'x-amz-checksum-type': 'FULL_OBJECT', 'x-amz-server-side-encryption': 'AES256', 'x-amz-meta-content-source': 'AmazonBedrock', 'x-amz-meta-content-additional-params': 'requestId="277fc051-6d33-4df6-bf47-6bffc7bb6568", signedContentSHA384="MGUCMQDQyUEv/DhkheQiV+t2sXxnuvgPjL1CYGoPkjVL+cWKPf3I5wNBne1t0o2Bv5ukocoCMBTB/76nJWvyOfYIlnUwpqPEvK7xHFB5SMAX+Zp0mTQYYPYbpaRVIGyaWOlJtlY+SQAAAAAAAAAB"', 'x-amz-meta-content-model-id': 'arn:aws:bedrock:us-east-1::foundation-model/amazon.nova-reel-v1:0', 'Accept-Ranges': 'bytes', 'Content-Type': 'application/octet-stream', 'Content-Length': '2307172', 'Server': 'AmazonS3'}
# [DEBUG] Response body:
# <botocore.httpchecksum.StreamingChecksumBody object at 0x000002184E746680>
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <function _update_status_code at 0x000002183BF6E480>
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <botocore.retryhandler.RetryHandler object at 0x000002184CC28F50>
# [DEBUG] No retry needed.
# [DEBUG] Event needs-retry.s3.GetObject: calling handler <bound method S3RegionRedirectorv2.redirect_from_error of <botocore.utils.S3RegionRedirectorv2 object at 0x000002184BB7C830>>
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 0}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 0}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 0}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 0}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 262144}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 262144}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 262144}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 262144}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 524288}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 524288}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 524288}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 524288}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 786432}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 786432}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 786432}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 786432}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1048576}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1048576}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1048576}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 1048576}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1310720}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1310720}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1310720}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 1310720}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1572864}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1572864}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1572864}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 1572864}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1835008}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 1835008}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 1835008}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 1835008}
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2097152}) about to wait for the following futures []
# [DEBUG] IOWriteTask(transfer_id=0, {'offset': 2097152}) done waiting for dependent futures
# [DEBUG] Executing task IOWriteTask(transfer_id=0, {'offset': 2097152}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'offset': 2097152}
# [DEBUG] IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-06_18-11-43_ug5stryadw0k\\ug5stryadw0k.mp4'}) about to wait for the following futures []
# [DEBUG] IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-06_18-11-43_ug5stryadw0k\\ug5stryadw0k.mp4'}) done waiting for dependent futures
# [DEBUG] Executing task IORenameFileTask(transfer_id=0, {'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-06_18-11-43_ug5stryadw0k\\ug5stryadw0k.mp4'}) with kwargs {'fileobj': <s3transfer.utils.DeferredOpenFile object at 0x000002184E78D010>, 'final_filename': 'c:\\Users\\mouhand\\Documents\\Python\\bedrock\\output\\2025-02-06_18-11-43_ug5stryadw0k\\ug5stryadw0k.mp4', 'osutil': <s3transfer.utils.OSUtils object at 0x000002184D5BB620>}
# [DEBUG] Releasing acquire 0/None
# [INFO] Downloaded video file: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-06_18-11-43_ug5stryadw0k\ug5stryadw0k.mp4
# [INFO] Saved completed job details to c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-06_18-11-43_ug5stryadw0k\completed.json
# [INFO]
# Video successfully generated and downloaded to: c:\Users\mouhand\Documents\Python\bedrock\output\2025-02-06_18-11-43_ug5stryadw0k\ug5stryadw0k.mp4
